# %% [markdown]
# # Belajar cara menggunakan pandas

# %% [markdown]
# Pertama-tama kita perlu mengimport pandas, dan kita mengimportanya dengan inisial 'pd'

# %%
import pandas as pd

# %% [markdown]
# Setelah mengimport pandas, dalam membuat initial data menggunakan pandas kita menggunakan Series dan DataFrame.
#
# Series ialah sekumpulan data. sedangkan DataFrame ialah sekumpulan Series.

# %% [markdown]
# Contoh Series

# %%
series = pd.Series([44, 70, 23, 12, 33, 54, 21, 78, 88, 23, 43, 45, '44'], name='Score')
series
# Out:
# 0     44
# 1     70
# 2     23
# 3     12
# 4     33
# 5     54
# 6     21
# 7     78
# 8     88
# 9     23
# 10    43
# 11    45
# 12    44
# dtype: object

# %% [markdown]
# Contoh DataFrame

# %%
dataframe = pd.DataFrame({
    'name': ['Ersapta', 'Yuda', 'Ayu'],
    'skill': ['Hadoken', 'Sharingan', None]
})

dataframe
# Out:
#       name      skill
# 0  Ersapta    Hadoken
# 1     Yuda  Sharingan
# 2      Ayu       None

# %% [markdown]
# selain membuat data secara mandiri, kita juga bisa membaca file menggunakan pandas, salah satunya ialah csv.

# %%
pandacsv = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/teams.csv')
pandacsv
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 4     FBS (Division I-A Teams)  American Athletic                   Memphis
# ..                         ...                ...                       ...
# 247  FCS (Division I-AA Teams)               SWAC             Jackson State
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
#
# ...

# %% [markdown]
# contoh menggunakan pandacsv.head() yang secara default menampilkan 5 data terdepan

# %%
pandacsv.head()
# Out:
#                                                 name  main_category  \
# 0      EIO New Born Baby Gift Set -13 Piecess (Pink)  kids' fashion
# 1  exciting Lives - Vintage Motorbike Pocket Watc...  kids' fashion
# 2  Jewel string by Bk arts Evil Eye Baby Nazaria ...  kids' fashion
# 3                    Superminis Unisex-baby's Bootie  kids' fashion
# 4  My Newborn Baby Mittens Caps Gloves and Booty ...  kids' fashion
#
#    sub_category                                              image  \
# 0  Baby Fashion  https://m.media-amazon.com/images/I/61X3IMp9dv...
# 1  Baby Fashion  https://m.media-amazon.com/images/I/71f3rkWNAF...
# 2  Baby Fashion  https://m.media-amazon.com/images/I/51Fc5epiN1...
# 3  Baby Fashion  https://m.media-amazon.com/images/I/71MNqAzGnA...
# 4  Baby Fashion  https://m.media-amazon.com/images/I/61CHRBjLTd...
#
#                                                 link ratings no_of_ratings  \
# ...

# %% [markdown]
# contoh menggunakan pandacsv.head() menampilkan data n terdepan, dimana n adalah jumlah data yang ingin ditampilkan

# %%
pandacsv.head(n= 10)
# Out:
#                                                 name  main_category  \
# 0      EIO New Born Baby Gift Set -13 Piecess (Pink)  kids' fashion
# 1  exciting Lives - Vintage Motorbike Pocket Watc...  kids' fashion
# 2  Jewel string by Bk arts Evil Eye Baby Nazaria ...  kids' fashion
# 3                    Superminis Unisex-baby's Bootie  kids' fashion
# 4  My Newborn Baby Mittens Caps Gloves and Booty ...  kids' fashion
# 5  DHRUVS COLLECTION 92.5 Pure Silver Black Beads...  kids' fashion
# 6  Bold N Elegant - Be Bold Inside & Elegant Outs...  kids' fashion
# 7            NPRC Unisex Wool Cap (436_Multicolor_M)  kids' fashion
# 8          SooWoo® Boy’s Anti-Skid Grip Cotton Socks  kids' fashion
# 9  Coolz Kids Chu-Chu Sound Musical First Walking...  kids' fashion
#
#    sub_category                                              image  \
# 0  Baby Fashion  https://m.media-amazon.com/images/I/61X3IMp9dv...
# 1  Baby Fashion  https://m.media-amazon.com/images/I/71f3rkWNAF...
# ...

# %% [markdown]
# contoh menggunakan pandacsv.tail() yang secara default menampilkan 5 data terakhir

# %%
pandacsv.tail()

# %% [markdown]
# contoh menggunakan pandacsv.tail() menampilkan data n terakhir, dimana n adalah jumlah data yang ingin ditampilkan

# %%
pandacsv.tail(n= 10)

# %% [markdown]
# contoh penggunaan pandacsv.shape, yang dimana menampilkan bentuk dari data yang diload dengan format (row, column)

# %%
pandacsv.shape
# Out:
# (2208, 9)

# %% [markdown]
# disini diketahui data yang kita miliki ialah 2208 baris dan 9 kolom

# %% [markdown]
# contoh penggunaan pandacsv.info(), yang dimana menampilkan kesimpulan dari data yang sudah diload, dan kita bisa mengetahui tipe data serta data non null dari masing-masing kolom

# %%
pandacsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2208 non-null   object
#  1   main_category   2208 non-null   object
#  2   sub_category    2208 non-null   object
#  3   image           2208 non-null   object
#  4   link            2208 non-null   object
#  5   ratings         1262 non-null   object
#  6   no_of_ratings   1262 non-null   object
#  7   discount_price  2032 non-null   object
#  8   actual_price    2152 non-null   object
# dtypes: object(9)
# memory usage: 155.4+ KB

# %% [markdown]
# contoh penggunaan pandacsv.describe(), yang dimana menampilkan hasil dari dasar statistik seperti count dan unique

# %%
pandacsv.describe()
# Out:
#                                                      name  main_category  \
# count                                                2208           2208
# unique                                               2101              1
# top     ARVESA Monthly Birthday Milestone Special Unis...  kids' fashion
# freq                                                   19           2208
#
#         sub_category                                              image  \
# count           2208                                               2208
# unique             1                                               2146
# top     Baby Fashion  https://m.media-amazon.com/images/I/81t2m239-L...
# freq            2208                                                  5
#
#                                                      link ratings  \
# count                                                2208    1262
# unique                                               2208      36
# ...

# %% [markdown]
# contoh penggunaan pandacsv.columns(), yang dimana menampilkan seluruh nama kolom pada data yang sudah diload

# %%
pandacsv.columns
# Out:
# Index(['name', 'main_category', 'sub_category', 'image', 'link', 'ratings',
#        'no_of_ratings', 'discount_price', 'actual_price'],
#       dtype='object')

# %% [markdown]
# contoh penggunaan pandacsv.index(), yang dimana menampilkan info tentang index data yang diload, info start index, index akhirnya serta step per index

# %%
pandacsv.index
# Out:
# RangeIndex(start=0, stop=2208, step=1)

# %% [markdown]
# contoh penggunaan pandacsv.dtypes(), yang dimana menampilkan seluruh nama kolom beserta tipe data isian kolom tersebut

# %%
pandacsv.dtypes
# Out:
# name              object
# main_category     object
# sub_category      object
# image             object
# link              object
# ratings           object
# no_of_ratings     object
# discount_price    object
# actual_price      object
# dtype: object

# %% [markdown]
# contoh penggunaan pandacsv.isnull(), yang dimana menghasilkan boolean value dari masing masing data apakah null atau tidak

# %%
pandacsv.isnull()
# Out:
#        name  main_category  sub_category  image   link  ratings  \
# 0     False          False         False  False  False    False
# 1     False          False         False  False  False    False
# 2     False          False         False  False  False    False
# 3     False          False         False  False  False    False
# 4     False          False         False  False  False    False
# ...     ...            ...           ...    ...    ...      ...
# 2203  False          False         False  False  False     True
# 2204  False          False         False  False  False     True
# 2205  False          False         False  False  False    False
# 2206  False          False         False  False  False     True
# 2207  False          False         False  False  False    False
#
#       no_of_ratings  discount_price  actual_price
# 0             False           False         False
# 1             False           False         False
# ...

# %% [markdown]
# pandacsv.nunique()

# %%
pandacsv.nunique()
# Out:
# name              2101
# main_category        1
# sub_category         1
# image             2146
# link              2208
# ratings             36
# no_of_ratings      259
# discount_price     490
# actual_price       347
# dtype: int64

# %% [markdown]
# contoh penggunaan pandacsv.value_counts(), yang dimana menampilkan data serta total data tersebut

# %%
pandacsv.value_counts()
# Out:
# name                                                                                                                           main_category  sub_category  image                                                                                             link                                                                                                                                                                                     ratings  no_of_ratings  discount_price  actual_price
# 100% Organic Bamboo Cotton Unisex Solid Baby Pants Plain Pajama Solid Lower Leggings Newborn Pajami Diaper Fit Without Pri...  kids' fashion  Baby Fashion  https://m.media-amazon.com/images/I/51txaod+exL._AC_UL320_.jpg                                    https://www.amazon.in/Organic-Bamboo-Leggings-Newborn-Without/dp/B0BQ429KH9/ref=sr_1_9470?qid=1679221542&s=apparel&sr=1-9470                                                             4.4      3              ₹349            ₹699            1
# ...

# %%
pandacsv['ratings'].value_counts()
# Out:
# 5.0    150
# 4.0    145
# 3.8     89
# 4.2     80
# 3.9     78
# 3.7     75
# 4.1     66
# 3.6     61
# 4.3     49
# 3.4     48
# 3.5     48
# 4.4     45
# 3.0     45
# 4.5     44
# 3.2     33
# 4.6     31
# 1.0     31
# 3.3     29
# 4.7     21
# 3.1     16
# 2.5     15
# 2.0     13
# 2.6      7
# 2.7      7
# Get      6
# 2.9      6
# 2.4      4
# 4.8      4
# 2.3      4
# 2.8      3
# 2.2      2
# 1.5      2
# 1.9      2
# 1.3      1
# 1.4      1
# 1.7      1
# Name: ratings, dtype: int64

# %% [markdown]
# ## Sorting

# %% [markdown]
# ### sort values by column

# %%
pandacsv.sort_values(by='ratings', ascending=True)
# Out:
#                                                    name  main_category  \
# 680   TheYaYaCafe Bura na Mano Holi hai Matching Men...  kids' fashion
# 1471  NASA Winter Sweater Cotton Full Sleeve Romper ...  kids' fashion
# 770   Rsmart Non-Slip Cotton Floral Print Ribbon Clo...  kids' fashion
# 748   SRCREATIONS Baby Girl's&Boys's Polycotton Prin...  kids' fashion
# 364   Decent Apparel SunLook Girl's Dress Girls Ethn...  kids' fashion
# ...                                                 ...            ...
# 2200  6 To 12 Months / 1 Year Baby Boys & Baby Girls...  kids' fashion
# 2201  My Bub Midi Frock | Printed Frock with Shorts|...  kids' fashion
# 2203  Aswadh Cute Cartoon Animal Uni Kids Toddler So...  kids' fashion
# 2204  B 4 Baby - Vest for Kids & Baby, Cotton Sando ...  kids' fashion
# 2206  Aswadh Cute Cartoon Animal Uni Kids Fleece Sho...  kids' fashion
#
#       sub_category                                              image  \
# ...

# %% [markdown]
# ## Slicing
# mengakses spesifik kolom / baris

# %% [markdown]
# ### Mengakses spesifik kolom

# %%
pandacsv['name']
# Out:
# 0           EIO New Born Baby Gift Set -13 Piecess (Pink)
# 1       exciting Lives - Vintage Motorbike Pocket Watc...
# 2       Jewel string by Bk arts Evil Eye Baby Nazaria ...
# 3                         Superminis Unisex-baby's Bootie
# 4       My Newborn Baby Mittens Caps Gloves and Booty ...
#                               ...
# 2203    Aswadh Cute Cartoon Animal Uni Kids Toddler So...
# 2204    B 4 Baby - Vest for Kids & Baby, Cotton Sando ...
# 2205    KETKAR Baby Gloves Winter Warm Lovely Knitted ...
# 2206    Aswadh Cute Cartoon Animal Uni Kids Fleece Sho...
# 2207    Cuckoos New Born Baby Boys & Girls 100% Cotton...
# Name: name, Length: 2208, dtype: object

# %%
pandacsv[['name', 'actual_price']]
# Out:
#                                                    name actual_price
# 0         EIO New Born Baby Gift Set -13 Piecess (Pink)       ₹1,499
# 1     exciting Lives - Vintage Motorbike Pocket Watc...         ₹699
# 2     Jewel string by Bk arts Evil Eye Baby Nazaria ...         ₹799
# 3                       Superminis Unisex-baby's Bootie         ₹899
# 4     My Newborn Baby Mittens Caps Gloves and Booty ...         ₹900
# ...                                                 ...          ...
# 2203  Aswadh Cute Cartoon Animal Uni Kids Toddler So...       ₹1,860
# 2204  B 4 Baby - Vest for Kids & Baby, Cotton Sando ...         ₹999
# 2205  KETKAR Baby Gloves Winter Warm Lovely Knitted ...         ₹299
# 2206  Aswadh Cute Cartoon Animal Uni Kids Fleece Sho...       ₹2,473
# 2207  Cuckoos New Born Baby Boys & Girls 100% Cotton...         ₹899
#
# [2208 rows x 2 columns]

# %% [markdown]
# ### Mengakses Spesifik Baris

# %%
pandacsv.iloc[10:20]
# Out:
#                                                  name  main_category  \
# 10  vaghbhatt baby hair band Multi-Colour Nylon La...  kids' fashion
# 11  LuvLap 100% Cotton Baby Caps, Mittens and Boot...  kids' fashion
# 12  Kids Fitness Tracker Watch for Girls Boys, Dig...  kids' fashion
# 13  CHIU Chu-Chu Black Shoes with Double Strap for...  kids' fashion
# 14  Wearville New Born Baby Boy's & Baby Girls jab...  kids' fashion
# 15  DHRUVS COLLECTION Exclusive BIS Hallmarked 925...  kids' fashion
# 16  Luv Lap Liquid Cleanser, Anti-Bacterial, Food ...  kids' fashion
# 17  CUTEABLY unisex-baby Multicolored Booties - 6 ...  kids' fashion
# 18  DKNY Unisex-Child Stassi Menia (Little Big Kid...  kids' fashion
# 19  Li'l Cupid Regular Fit Hooded Fleece Sweatshir...  kids' fashion
#
#     sub_category                                              image  \
# 10  Baby Fashion  https://m.media-amazon.com/images/I/614nSuPIhW...
# 11  Baby Fashion  https://m.media-amazon.com/images/I/71XG9Mly8U...
# ...

# %%
pandacsv.iloc[10:]
# Out:
#                                                    name  main_category  \
# 10    vaghbhatt baby hair band Multi-Colour Nylon La...  kids' fashion
# 11    LuvLap 100% Cotton Baby Caps, Mittens and Boot...  kids' fashion
# 12    Kids Fitness Tracker Watch for Girls Boys, Dig...  kids' fashion
# 13    CHIU Chu-Chu Black Shoes with Double Strap for...  kids' fashion
# 14    Wearville New Born Baby Boy's & Baby Girls jab...  kids' fashion
# ...                                                 ...            ...
# 2203  Aswadh Cute Cartoon Animal Uni Kids Toddler So...  kids' fashion
# 2204  B 4 Baby - Vest for Kids & Baby, Cotton Sando ...  kids' fashion
# 2205  KETKAR Baby Gloves Winter Warm Lovely Knitted ...  kids' fashion
# 2206  Aswadh Cute Cartoon Animal Uni Kids Fleece Sho...  kids' fashion
# 2207  Cuckoos New Born Baby Boys & Girls 100% Cotton...  kids' fashion
#
#       sub_category                                              image  \
# ...

# %%
pandacsv.iloc[:20]
# Out:
#                                                  name  main_category  \
# 0       EIO New Born Baby Gift Set -13 Piecess (Pink)  kids' fashion
# 1   exciting Lives - Vintage Motorbike Pocket Watc...  kids' fashion
# 2   Jewel string by Bk arts Evil Eye Baby Nazaria ...  kids' fashion
# 3                     Superminis Unisex-baby's Bootie  kids' fashion
# 4   My Newborn Baby Mittens Caps Gloves and Booty ...  kids' fashion
# 5   DHRUVS COLLECTION 92.5 Pure Silver Black Beads...  kids' fashion
# 6   Bold N Elegant - Be Bold Inside & Elegant Outs...  kids' fashion
# 7             NPRC Unisex Wool Cap (436_Multicolor_M)  kids' fashion
# 8           SooWoo® Boy’s Anti-Skid Grip Cotton Socks  kids' fashion
# 9   Coolz Kids Chu-Chu Sound Musical First Walking...  kids' fashion
# 10  vaghbhatt baby hair band Multi-Colour Nylon La...  kids' fashion
# 11  LuvLap 100% Cotton Baby Caps, Mittens and Boot...  kids' fashion
# 12  Kids Fitness Tracker Watch for Girls Boys, Dig...  kids' fashion
# ...

# %% [markdown]
# ## Query / Filtering

# %% [markdown]
# ### Query

# %%
pandacsv.query("ratings >= '2' and ratings <= '3'")
# Out:
#                                                    name  main_category  \
# 73    Neska Moda Months Baby Boys Synthetic Leather ...  kids' fashion
# 78    Pooja Baby 100% Cotton Rompers/Sleepsuits/Jump...  kids' fashion
# 94    DARSHRAJ JEWELLERS 925 Sterling Silver kada fo...  kids' fashion
# 103   Traditional Silver & Black Nazariya Beads For ...  kids' fashion
# 105                        Mozzo Baby boy & Girls Shoes  kids' fashion
# ...                                                 ...            ...
# 1738  Kidbee Baby Soft Super Cotton Hosiery Boys & B...  kids' fashion
# 1830  Nino Bambino 100% Organic Cotton Printed Long ...  kids' fashion
# 2041  HIYA Baby Boys/Girls Winter Wear Thermal Set W...  kids' fashion
# 2052  BAYBEE Supersoft Cotton Baby Mittens, Booties ...  kids' fashion
# 2143  Adorazone® Kid's Super-Warm Velvet Thermal Ank...  kids' fashion
#
#       sub_category                                              image  \
# ...

# %%
# hanya bisa 1 karena bukan label-based indexing
pandacsv.loc[pandacsv['ratings'] > '5']
# Out:
#                                                    name  main_category  \
# 22    Neska Moda 6 To 12 Months Baby Girls Synthetic...  kids' fashion
# 53    WILDBIRDS Kids Girls Shoes for 12 Months to 10...  kids' fashion
# 70    Neska Moda 0 To 6 Months Baby Boys & Girls Pac...  kids' fashion
# 74    superbottoms Top & Shorts Set | Evrydaywear| C...  kids' fashion
# 81                        KingSwagger Sneakers for Kids  kids' fashion
# ...                                                 ...            ...
# 2172            Gini & Jony Boys Round Neck Printed Tee  kids' fashion
# 2175  MINI KLUB Baby Boy's Cotton Cap (95IEBCP569_Of...  kids' fashion
# 2187  Neska Moda Baby Boys and Girls Pack of 4 Cotto...  kids' fashion
# 2195  Nutshell Baby Clothing Set for Boys & Girls | ...  kids' fashion
# 2202  ARIF Collection Baby Girls Calf Length Casual ...  kids' fashion
#
#       sub_category                                              image  \
# ...

# %% [markdown]
# Pertama-tama mari convert value pada kolom actual_price terlebih dahulu

# %%
pandacsv['actual_price_int'] = pandacsv['actual_price'].str.replace('₹', '').str.replace(',', '')
pandacsv['actual_price_int'] = pandacsv['actual_price_int'].astype(float)

pandacsv
# Out:
#                                                    name  main_category  \
# 0         EIO New Born Baby Gift Set -13 Piecess (Pink)  kids' fashion
# 1     exciting Lives - Vintage Motorbike Pocket Watc...  kids' fashion
# 2     Jewel string by Bk arts Evil Eye Baby Nazaria ...  kids' fashion
# 3                       Superminis Unisex-baby's Bootie  kids' fashion
# 4     My Newborn Baby Mittens Caps Gloves and Booty ...  kids' fashion
# ...                                                 ...            ...
# 2203  Aswadh Cute Cartoon Animal Uni Kids Toddler So...  kids' fashion
# 2204  B 4 Baby - Vest for Kids & Baby, Cotton Sando ...  kids' fashion
# 2205  KETKAR Baby Gloves Winter Warm Lovely Knitted ...  kids' fashion
# 2206  Aswadh Cute Cartoon Animal Uni Kids Fleece Sho...  kids' fashion
# 2207  Cuckoos New Born Baby Boys & Girls 100% Cotton...  kids' fashion
#
#       sub_category                                              image  \
# ...

# %%
del pandacsv['actual_price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'actual_price'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pandacsv
# Out:
#                                                    name  main_category  \
# 0         EIO New Born Baby Gift Set -13 Piecess (Pink)  kids' fashion
# 1     exciting Lives - Vintage Motorbike Pocket Watc...  kids' fashion
# 2     Jewel string by Bk arts Evil Eye Baby Nazaria ...  kids' fashion
# 3                       Superminis Unisex-baby's Bootie  kids' fashion
# 4     My Newborn Baby Mittens Caps Gloves and Booty ...  kids' fashion
# ...                                                 ...            ...
# 2203  Aswadh Cute Cartoon Animal Uni Kids Toddler So...  kids' fashion
# 2204  B 4 Baby - Vest for Kids & Baby, Cotton Sando ...  kids' fashion
# 2205  KETKAR Baby Gloves Winter Warm Lovely Knitted ...  kids' fashion
# 2206  Aswadh Cute Cartoon Animal Uni Kids Fleece Sho...  kids' fashion
# 2207  Cuckoos New Born Baby Boys & Girls 100% Cotton...  kids' fashion
#
#       sub_category                                              image  \
# ...

# %%
pandacsv['actual_price_int'].mean()
# Out:
# 1285.6823977695165

# %%
pandacsv.groupby('ratings')['name'].count()
# Out:
# ratings
# 1.0     31
# 1.3      1
# 1.4      1
# 1.5      2
# 1.7      1
# 1.9      2
# 2.0     13
# 2.2      2
# 2.3      4
# 2.4      4
# 2.5     15
# 2.6      7
# 2.7      7
# 2.8      3
# 2.9      6
# 3.0     45
# 3.1     16
# 3.2     33
# 3.3     29
# 3.4     48
# 3.5     48
# 3.6     61
# 3.7     75
# 3.8     89
# 3.9     78
# 4.0    145
# 4.1     66
# 4.2     80
# 4.3     49
# 4.4     45
# 4.5     44
# 4.6     31
# 4.7     21
# 4.8      4
# 5.0    150
# Get      6
# Name: name, dtype: int64
