# %%
import pandas as pd

# %%
df = pd.read_csv('universal_top_spotify_songs.csv')
df
# Out:
#                    spotify_id  \
# 0      0AYt6NMyyLd0rLuvr0UkMH
# 1      2V2K1hzCtgj9xAnga9WUTy
# 2      1CrwpdodnkXcjPSrg8kw9g
# 3      6HmiaxYKrzq3sU2M0eFDg2
# 4      4tsVMjM60RNTe9EV5oQ4sQ
# ...                       ...
# 29108  7iQXYTyuG13aoeHxGG28Nh
# 29109  2HafqoJbgXdtjwCOvNEF14
# 29110  56y1jOTK0XSvJzVv9vHQBK
# 29111  7x9aauaA9cu6tyfpHnqDLo
# 29112  4MjDJD8cW7iVeWInc2Bdyj
#
#                                                     name  \
# 0                              Slime You Out (feat. SZA)
# 1                       Horns In The Sun - Thakzin Remix
# 2      Gangnam Style (feat. DJ Maphorisa & Kabza De S...
# 3                                             BETTER NOW
# 4                                            Masithokoze
# ...                                                  ...
# 29108                                        PERRO NEGRO
# 29109                                        Si No Estás
# 29110                                 Paint The Town Red
# ...
